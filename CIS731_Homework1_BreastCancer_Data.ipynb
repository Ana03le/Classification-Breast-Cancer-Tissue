# %%
########################
## CIS 731 HOMEWORK1  ##
## Anagha Fatale      ##
## SUID 438039600     ##
########################

import pandas as pd
import keras
from keras import backend as k
import numpy as np
import tensorflow as tf
from dummyPy import OneHotEncoder
from sklearn.preprocessing import OneHotEncoder, LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from keras.utils.generic_utils import get_custom_objects
from math import exp
from random import seed
from random import random
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
import matplotlib.pyplot as plt 





def CustomSigmoid(x):
    return k.sigmoid(x)

def CustomSigmoid1(x):
    a = []
    for item in x:
        a.append(1/1+exp(-item))
    return a 
     


def piecsewise_linear_04_segment(X):
    n = 4
    x_axis = np.arange(-10., 10., 0.1)
    y_axis = CustomSigmoid1(x_axis)
    x_points = x_axis[0:len(x_axis):int(len(x_axis)/n-1)]
    y_points = y_axis[0:len(y_axis):int(len(x_axis)/n-1)]
    slope = np.zeros(len(x_axis)-1)
    delta = np.zeros(len(x_axis)-1)
    for i in range(len(x_points)-1):
        slope[i] = (y_points[i+1]-y_points[i])/(x_points[i+1]-x_points[i])
        delta[i] = y_points[i]-(slope[i]*x_points[i])
        
    return (k.switch(X<x_points[0],0*X,k.switch(X<=x_points[1],slope[0]*X + delta[0],k.switch(X<=x_points[2],slope[1]*X + delta[1],k.switch(X<=x_points[3],slope[2]*X + delta[2],0*X+1)))))
        


    
def piecsewise_linear_06_segment(X):
    n = 6
    x_axis = np.arange(-10., 10., 0.1)
    y_axis = CustomSigmoid1(x_axis)
    x_points = x_axis[0:len(x_axis):int(len(x_axis)/n-1)]
    y_points = y_axis[0:len(y_axis):int(len(x_axis)/n-1)]
    slope = np.zeros(len(x_points)-1)
    delta = np.zeros(len(x_points)-1)
    for i in range(len(x_points)-1):
        slope[i] = (y_points[i+1]-y_points[i])/(x_points[i+1]-x_points[i])
        delta[i] = y_points[i]-(slope[i]*x_points[i])  
   
    return (k.switch(X<x_points[0],0*X,k.switch(X<=x_points[1],slope[0]*X + delta[0],k.switch(X<=x_points[2],slope[1]*X + delta[1],k.switch(X<=x_points[3],slope[2]*X + delta[2],k.switch(X<=x_points[4],slope[3]*X + delta[3],k.switch(X<=x_points[5],slope[4]*X + delta[4], 0*X+1)))))))
    


    
    
def piecsewise_linear_08_segment(X):
    n = 8
    x_axis = np.arange(-10., 10., 0.1)
    y_axis = CustomSigmoid1(x_axis)
    x_points = x_axis[0:len(x_axis):int(len(x_axis)/n-1)]
    y_points = y_axis[0:len(y_axis):int(len(x_axis)/n-1)]
    slope = np.zeros(len(x_points)-1)
    delta = np.zeros(len(x_points)-1)
    for i in range(len(x_points)-1):
        slope[i] = (y_points[i+1]-y_points[i])/(x_points[i+1]-x_points[i])
        delta[i] = y_points[i]-(slope[i]*x_points[i])  
   
    return (k.switch(X<x_points[0],0*X,k.switch(X<=x_points[1],slope[0]*X + delta[0],k.switch(X<=x_points[2],slope[1]*X + delta[1],k.switch(X<=x_points[3],slope[2]*X + delta[2],k.switch(X<=x_points[4],slope[3]*X + delta[3],k.switch(X<=x_points[5],slope[4]*X + delta[4],k.switch(X<=x_points[6],slope[5]*X + delta[5],k.switch(X<=x_points[7],slope[6]*X + delta[6], 0*X+1)))))))))
    
    
def piecsewise_linear_10_segment(X):
    n = 10
    x_axis = np.arange(-10., 10., 0.1)
    y_axis = CustomSigmoid1(x_axis)
    x_points = x_axis[0:len(x_axis):int(len(x_axis)/n-1)]
    y_points = y_axis[0:len(y_axis):int(len(x_axis)/n-1)]
    slope = np.zeros(len(x_points)-1)
    delta = np.zeros(len(x_points)-1)
    for i in range(len(x_points)-1):
        slope[i] = (y_points[i+1]-y_points[i])/(x_points[i+1]-x_points[i])
        delta[i] = y_points[i]-(slope[i]*x_points[i])  
   
    return (k.switch(X<x_points[0],0*X,k.switch(X<=x_points[1],slope[0]*X + delta[0],k.switch(X<=x_points[2],slope[1]*X + delta[1],k.switch(X<=x_points[3],slope[2]*X + delta[2],k.switch(X<=x_points[4],slope[3]*X + delta[3],k.switch(X<=x_points[5],slope[4]*X + delta[4],k.switch(X<=x_points[6],slope[5]*X + delta[5],k.switch(X<=x_points[7],slope[6]*X + delta[6],k.switch(X<=x_points[8],slope[7]*X + delta[7],k.switch(X<=x_points[9],slope[8]*X + delta[8], 0*X+1)))))))))))
    
    

    
def piecsewise_linear_12_segment(X):
    n = 12
    x_axis = np.arange(-10., 10., 0.1)
    y_axis = CustomSigmoid1(x_axis)
    x_points = x_axis[0:len(x_axis):int(len(x_axis)/n-1)]
    y_points = y_axis[0:len(y_axis):int(len(x_axis)/n-1)]
    slope = np.zeros(len(x_points)-1)
    delta = np.zeros(len(x_points)-1)
    for i in range(len(x_points)-1):
        slope[i] = (y_points[i+1]-y_points[i])/(x_points[i+1]-x_points[i])
        delta[i] = y_points[i]-(slope[i]*x_points[i])  
   
    return (k.switch(X<x_points[0],0*X,k.switch(X<=x_points[1],slope[0]*X + delta[0],k.switch(X<=x_points[2],slope[1]*X + delta[1],k.switch(X<=x_points[3],slope[2]*X + delta[2],k.switch(X<=x_points[4],slope[3]*X + delta[3],k.switch(X<=x_points[5],slope[4]*X + delta[4],k.switch(X<=x_points[6],slope[5]*X + delta[5],k.switch(X<=x_points[7],slope[6]*X + delta[6],k.switch(X<=x_points[8],slope[7]*X + delta[7],k.switch(X<=x_points[9],slope[8]*X + delta[8],k.switch(X<=x_points[10],slope[9]*X + delta[9],k.switch(X<=x_points[11],slope[10]*X + delta[10], 0*X+1)))))))))))))




def piecsewise_linear_14_segment(X):
    n = 14
    x_axis = np.arange(-10., 10., 0.1)
    y_axis = CustomSigmoid1(x_axis)
    x_points = x_axis[0:len(x_axis):int(len(x_axis)/n-1)]
    y_points = y_axis[0:len(y_axis):int(len(x_axis)/n-1)]
    slope = np.zeros(len(x_axis)-1)
    delta = np.zeros(len(x_axis)-1)
    for i in range(len(x_points)-1):
        slope[i] = (y_points[i+1]-y_points[i])/(x_points[i+1]-x_points[i])
        delta[i] = y_points[i]-(slope[i]*x_points[i])  
   
    return (k.switch(X<x_points[0],0*X,k.switch(X<=x_points[1],slope[0]*X + delta[0],k.switch(X<=x_points[2],slope[1]*X + delta[1],k.switch(X<=x_points[3],slope[2]*X + delta[2],k.switch(X<=x_points[4],slope[3]*X + delta[3],k.switch(X<=x_points[5],slope[4]*X + delta[4],k.switch(X<=x_points[6],slope[5]*X + delta[5],k.switch(X<=x_points[7],slope[6]*X + delta[6],k.switch(X<=x_points[8],slope[7]*X + delta[7],k.switch(X<=x_points[9],slope[8]*X + delta[8],k.switch(X<=x_points[10],slope[9]*X + delta[9],k.switch(X<=x_points[11],slope[10]*X + delta[10],k.switch(X<=x_points[12],slope[11]*X + delta[11],k.switch(X<=x_points[13],slope[12]*X + delta[12],0*X+1)))))))))))))))


new_data = pd.read_csv("dataR21.csv")           
new_data.fillna(new_data.mean,inplace= True)            
            

data =np.array(new_data)
#data = pd.DataFrame(new_data)
#data = data.dropna()
#data=data[data.Bland_Chromatin == '?']
output_data = data[:,-1]
#['Classification']



input_data = data[:,0:-1] 
#.drop(columns=['Classification'])
#input_data.info
#print(input_data)



input_train, input_test, output_train, output_test = train_test_split(input_data, output_data, test_size=0.10)
#index,output=np.split('\t')
#print(output_train)

sc = StandardScaler()

input_train = sc.fit_transform(input_train) 
input_test = sc.transform(input_test)

networkModel = Sequential()


#get_custom_objects().update({'CustomSigmoid': Activation(CustomSigmoid)})
#networkModel.add(Activation(CustomSigmoid))

#get_custom_objects().update({'piecsewise_linear_04_segment': Activation(piecsewise_linear_04_segment)})
#networkModel.add(Activation(piecsewise_linear_04_segment))


#get_custom_objects().update({'piecsewise_linear_06_segment': Activation(piecsewise_linear_04_segment)})
#networkModel.add(Activation(piecsewise_linear_06_segment))

#get_custom_objects().update({'piecsewise_linear_08_segment': Activation(piecsewise_linear_04_segment)})
#networkModel.add(Activation(piecsewise_linear_08_segment))

#get_custom_objects().update({'piecsewise_linear_10_segment': Activation(piecsewise_linear_04_segment)})
#networkModel.add(Activation(piecsewise_linear_10_segment))

#get_custom_objects().update({'piecsewise_linear_12_segment': Activation(piecsewise_linear_12_segment)})
#networkModel.add(Activation(piecsewise_linear_12_segment))

get_custom_objects().update({'piecsewise_linear_14_segment': Activation(piecsewise_linear_14_segment)})
networkModel.add(Activation(piecsewise_linear_14_segment))


networkModel.add(Dense(units = 18, kernel_initializer = 'uniform',activation = piecsewise_linear_14_segment, input_dim = 9))

networkModel.add(Dense(units = 1, kernel_initializer = 'uniform',activation = 'sigmoid' ))

networkModel.compile(optimizer='sgd', loss='mse', metrics=['accuracy'])

networkModel.fit(input_train,output_train,batch_size = 8, epochs=50)


#networkModel.evaluate(input_test, output_test, batch_size= 60)

#Value = networkModel.predict(input_test, batch_size=None, verbose=0, steps=None)
# Out:
# /Users/anaghafatale/anaconda3/lib/python3.6/site-packages/sklearn/utils/validation.py:475: DataConversionWarning: Data with input dtype int64 was converted to float64 by StandardScaler.
#   warnings.warn(msg, DataConversionWarning)
# Epoch 1/50
# 613/613 [==============================] - 1s 969us/step - loss: 0.2315 - acc: 0.6297
# Epoch 2/50
# 613/613 [==============================] - 0s 181us/step - loss: 0.2191 - acc: 0.6493
# Epoch 3/50
# 613/613 [==============================] - 0s 174us/step - loss: 0.2133 - acc: 0.6493
# Epoch 4/50
# 613/613 [==============================] - 0s 184us/step - loss: 0.1671 - acc: 0.7259
# Epoch 5/50
# 613/613 [==============================] - 0s 185us/step - loss: 0.0935 - acc: 0.9233
# Epoch 6/50
# 613/613 [==============================] - 0s 184us/step - loss: 0.0463 - acc: 0.9723
# Epoch 7/50
# 613/613 [==============================] - 0s 178us/step - loss: 0.0295 - acc: 0.9755
# Epoch 8/50
# ...
